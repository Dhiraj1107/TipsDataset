# %%
import seaborn as sns
import pandas as pd

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.day.unique()
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %%
tips.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
tips.day.value_counts().plot(kind='bar')

# %%
tips.time.value_counts(normalize=True)
# Out:
# Dinner    0.721311
# Lunch     0.278689
# Name: time, dtype: float64

# %%
tips.groupby(['time'])['tip'].mean().plot.bar()

# %%
tips.groupby(['sex'])['tip'].mean().plot.bar()

# %%
tips.groupby(['smoker'])['tip'].mean().plot.bar()

# %%
tips.groupby(['size'])['tip'].mean().plot.bar()

# %%
tips.groupby(['smoker','sex'])['tip'].mean().unstack()
# Out:
# sex         Male    Female
# smoker
# Yes     3.051167  2.931515
# No      3.113402  2.773519

# %%
tips.groupby(['smoker','sex'])['tip'].mean()
# Out:
# smoker  sex
# Yes     Male      3.051167
#         Female    2.931515
# No      Male      3.113402
#         Female    2.773519
# Name: tip, dtype: float64

# %%
tips.groupby(['smoker','day'])['tip'].mean().unstack()
# Out:
# day         Thur     Fri       Sat       Sun
# smoker
# Yes     3.030000  2.7140  2.875476  3.516842
# No      2.673778  2.8125  3.102889  3.167895

# %%
tips['tips_per']=(tips.tip/tips.total_bill)*100
tips_per.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-7e658c97c248> in <module>
#       1 tips['tips_per']=(tips.tip/tips.total_bill)*100
# ----> 2 tips_per.head()
#
# NameError: name 'tips_per' is not defined

# %%
tips['tips_per']=(tips.tip/tips.total_bill)*100

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tips_per
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3  16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2  13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4  14.680765

# %%
tips.plot.scatter(x='total_bill',y='tip')

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips)

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips,hue='sex')

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips,hue='day')

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips,hue='time')

# %%
sns.relplot(x='total_bill',y='tip',data=tips,col='sex',hue='time')

# %%
sns.__version__
# Out:
# '0.11.0'

# %%
sns.pairplot(data=tips, hue="sex")

# %%
sns.displot (data=tips,x="total_bill",col="time",kde=True)
